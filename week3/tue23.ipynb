# %%
## 3D scatter plot 
import numpy as np
import matplotlib.pyplot as plt

z = np.array ([0,1,4,3,5,1,2,5,7,5,9,8,5])
fig = plt.figure()
ax = np.array([fig.add_subplot(1,3,1, projection = '3D'),
               ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/projections/__init__.py:120, in get_projection_class(projection)
#     119 try:
# --> 120     return projection_registry.get_projection_class(projection)
#     121 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/projections/__init__.py:83, in ProjectionRegistry.get_projection_class(self, name)
#      82 """Get a projection class from its *name*."""
# ---> 83 return self._all_projection_types[name]
#
# KeyError: '3D'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       5 z = np.array ([0,1,4,3,5,1,2,5,7,5,9,8,5])
#       6 fig = plt.figure()
# ----> 7 ax = np.array([fig.add_subplot(1,3,1, projection = '3D'),
#       8                ])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/figure.py:781, in FigureBase.add_subplot(self, *args, **kwargs)
#     778 if (len(args) == 1 and isinstance(args[0], Integral)
#     779         and 100 <= args[0] <= 999):
#     780     args = tuple(map(int, str(args[0])))
# --> 781 projection_class, pkw = self._process_projection_requirements(**kwargs)
#     782 ax = projection_class(self, *args, **pkw)
#     783 key = (projection_class, pkw)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/figure.py:1718, in FigureBase._process_projection_requirements(self, axes_class, polar, projection, **kwargs)
#    1715     projection = 'polar'
#    1717 if isinstance(projection, str) or projection is None:
# -> 1718     projection_class = projections.get_projection_class(projection)
#    1719 elif hasattr(projection, '_as_mpl_axes'):
#    1720     projection_class, extra_kwargs = projection._as_mpl_axes()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/projections/__init__.py:122, in get_projection_class(projection)
#     120     return projection_registry.get_projection_class(projection)
#     121 except KeyError as err:
# --> 122     raise ValueError("Unknown projection %r" % projection) from err
#
# ValueError: Unknown projection '3D'

# %%
## bar plot 

people = ['StudentA', 'StudentB']
StudentA = np.array([90,60,80,40])
StudentB = np.array([75,45,60,95])
p = np.arange(len(StudentA))
fig, ax = plt.subplots(1,2)

#ax[0].bar(p, StudentA)
#ax[1].bar(p, StudentB)

# FROM THIS WE CAN ADD WIDTH, LEGNEDS ETC LIKE YDAY
ax[0].bar(p, StudentA, width = 0.5)
ax[1].bar(p, StudentB, width = 0.5)
fig.tight_layout()

for i in range(len(ax)):
    ax[i].set_ylim(0,100)
    ax[i].set_title('People')
    ax[i].set_xlabel('Exercises')
    ax[i].set_ylabel('Mark (%)')
    ax[i].set_xticks([0,1,2,3])
    ax[i].set_xticklabels(['ex1', 'ex2' , 'ex3', 'ex4'])

fig, ax = plt.subplots()
width = 0.3
s1bars = ax.bar(p-width/2, StudentA, width)
s2bars = ax.bar(p+width/2, StudentB, width)

for i in range(len(StudentA)):
    s1bars[i].set_linewidth(3.5)
    s2bars[i].set_linewidth(3.5)
    if StudentA[i] < 50:
        s1bars[i].set_edgecolor('red')
    if StudentB[i] < 50:
        s2bars[i].set_edgecolor('red')

# %%
fig, ax = plt.subplots()
width = 0.3
s1bars = ax.bar(p-width/2, StudentA, width)
s2bars = ax.bar(p+width/2, StudentB, width)

# %%
## create visual art shapes

from matplotlib.patches import Polygon

# %%
fig, ax = plt.subplots()
ax.set_ylim([0,20])
ax.set_xlim([-10,10])
ax.axis('scaled')
start_x = -2.5
start_y = 2
width = 5
height = 6
facecolor = 'pink'

## creating th rectangle 

rec = plt.Rectangle((start_x, start_y), width, height, fc = facecolor)
ax.add_patch(rec)

## add patch

rec1 = plt.Rectangle((-0.5, 2), 1, 2, fc = 'brown')
ax.add_patch(rec1)

## add a circle
# becarful of function Circle with capital C, when naming varible 
circle1 = plt.Circle((-1,6), 0.5, fc = 'lightyellow', edgecolor = 'red', lw=1)
ax.add_patch(circle1)

## add a circle 2
circle2 = plt.Circle((1,6), 0.5, fc = 'lightyellow', edgecolor = 'red', lw=1)
ax.add_patch(circle2)

#add a triangle 
start_xy = np.array([-2.5,8])
end_xy = np.array([2.5,8])
top_xy = np.array([0,10])
tri = Polygon(np.vstack([start_xy,end_xy,top_xy]), color = 'hotpink')
ax.add_patch(tri)
fig.tight_layout()

# %%
##save the output 
filename = 'pinkhouse.jpeg'
plt.savefig( filename, format = 'jpeg')

# %%
##2hrs 30 mins 

import numpy as np
# load dataset which was possible with numpy loadtxt fuction
data_raw = np.loadtxt("i/Users/thuyduong/Downloads/iris-head-num.txt", delimiter=',', dtype='object')

#get the header first row od data set

# %%
# Get the Iris dataset
dataRaw = np.loadtxt("iris-head-num.txt", delimiter=',', dtype='object')
# Get the header (first row)
header = dataRaw[0,:]
# Get the data (second row till end; 1-4th columns). Convert them to float
data = dataRaw[1:,:4]
data = np.vstack(data.astype(np.float32))
# Get the labels (second row; 4th columns)
labels = np.vstack(dataRaw[1:,4].astype(np.int32))
# Find unique labels and frequency
labelsUn, labelsCounts = np.unique(labels, return_counts=True)

# Find average, maximum, minimum and stand deviation of each column per category
nrows,ncols = np.shape(data) #number of rows and columns
nclasses = len(labelsUn)     #number of unique categories
#Initialise an nclasses-by-ncols per statistic
average = np.zeros((nclasses,ncols)) #mean
maxi = np.zeros((nclasses,ncols))    #maximum
mini = np.zeros((nclasses,ncols))    #minimum
sd = np.zeros((nclasses,ncols))      #standard deviation
for i in labelsUn:
    indexes = np.reshape(labels==i,nrows)
    average[i-1,:] = np.mean(data[indexes,:],axis=0)
    maxi[i-1,:] = np.max(data[indexes,:],axis=0)
    mini[i-1,:] = np.min(data[indexes,:],axis=0)
    sd[i-1,:] = np.std(data[indexes,:],axis=0)
    
    
#Errorbars with standard deviation
species = np.array(['setosa','versicolor','virginica'])
features = np.array(header[:-1].astype("U"))
x = np.arange(len(features))

fig, ax = plt.subplots()
for i in labelsUn:
    ax.errorbar(x, average[i-1,:], sd[i-1,:], marker="o", label=species[i-1]) 

#Aesthetics    
ax.legend(loc="upper right")    
ax.set_xlabel("features", fontsize=14, fontweight='bold')
ax.set_ylabel("mean +/- sd", fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(features, rotation=45)
fig.tight_layout()  #make sure that the axes labels fit the figure


#Boxplots (1)-----------------------------------------------------
data0 = [12, 10, 100, 11, 3, 20]
print("data : ", data)  
print("Q1 quantile of data : ", np.quantile(data0, .25)) 
print("Q2 quantile of data : ", np.quantile(data0, .50)) 
print("Q3 quantile of data : ", np.quantile(data0, .75)) 
print("median of data : ", np.median(data0)) 
print("mean of data : ", np.mean(data0)) 
fig, ax = plt.subplots()
ax.boxplot(data0)

#Boxplots (2)-----------------------------------------------------
outliers = dict(marker='+', markerfacecolor='black')
medians = dict(linewidth=2)
boxes = np.array([dict(facecolor='r',color='r'),
                  dict(facecolor='g',color='g'), 
                  dict(facecolor='b',color='b')])
    
mylegend = [plt.scatter([0],[0],facecolor='r', edgecolor='r', label=species[0]),
            plt.scatter([0],[0],facecolor='g', edgecolor='g', label=species[1]),
            plt.scatter([0],[0],facecolor='b', edgecolor='b', label=species[2])]
plt.close("all") #make sure that no figure is generated

x = -7
step = 5
fig, ax = plt.subplots()

for j in range(len(features)): #for each feature...
    x+= 7
    for i in labelsUn:         #for each category...
        indexes = np.reshape(labels==i,nrows)
        temp = data[indexes,j]
        ax.boxplot(temp, positions=[x],
                   widths=2,
                   patch_artist=True,
                   medianprops=medians,
                   boxprops=boxes[i-1],
                   flierprops=outliers)
        x+= step

ax.set_title("iris data set", fontsize=13, fontweight='bold')
ax.set_ylabel("values", fontweight='bold')
ax.set_xticks(np.arange(step,x,22))
ax.set_xticklabels(features, fontweight='bold', rotation=45)
ax.legend(handles=mylegend)
fig.tight_layout()  #make sure that the axes labels fit the figure
