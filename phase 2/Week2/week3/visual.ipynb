# %%
## VISULISING DATA

# %% [markdown]
# what is the info telling us ?
#
# to help describe and understand the Earth; minimize loss of life and property from natural disasters; manage water, biological, energy, and mineral resources; and enhance and protect our quality of life.
#
# The data set contains details of all earthquakes that have happened in the last 30 days and is updated every 15 mins in the USGS website.

# %% [markdown]
# TASK
# Using the linked dataset below produce a series of visualisations demonstrating the use of Matplotlib.
#
# You should produce at least one of the following:
#
# Bar Graph.
# Pie Chart.
# Box Plot.
# Line Chart.
# Scatter Plot.
#
# Once you have demonstrated use of the different plots you should look at the data and make some conclusions from the data set. Can you find any links?
#
# Present your conclusion illustrated with appropriate visualisations.
#
# Submit your completed notebook.

# %% [markdown]
# What data I want to make based on the data:
#
# 1) Use nlargest to get the top 5 earthquakes by magnitude
#
# 2) Extract the place using Pandas text data functions to a bar chart
#
# 3) Visualize the locations of earthquakes by making a scatterplot of their latitude and longitude
# Use a two-column subplot with both the filtered and unfiltered datasets. Color the points by magnitude. Make it pretty

# %%
# firstly I will import the librares that i will need to create all the data visual graphs and plots 

import numpy as np # working with arrays and to perform a wide variety of mathematical operations on arrays
import matplotlib.pyplot as plt # for creating static, animated, and interactive visualizations in Python
import seaborn as sns # making statistical graphics in Python
import pandas as pd # for data manipulation and analysis

# %%
# import earthquake data set 

Earthquake = pd.read_csv('all_month.csv')
Earthquake.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2024-01-18T02:18:19.690Z  38.807835 -122.823334   2.03  1.49      md  21.0
# 1  2024-01-18T02:16:52.710Z  38.808498 -122.823669   2.01  1.33      md  23.0
# 2  2024-01-18T01:55:45.006Z  64.994500 -147.409700   5.20  1.50      ml   NaN
# 3  2024-01-18T01:48:21.130Z  36.020333 -117.781167   1.55  1.39      ml  27.0
# 4  2024-01-18T01:46:32.440Z  38.826668 -122.853836   2.44  0.28      md  10.0
#
#     gap      dmin   rms  ...                         place        type  \
# 0  54.0  0.004681  0.02  ...   7 km WNW of The Geysers, CA  earthquake
# 1  53.0  0.004320  0.02  ...   7 km WNW of The Geysers, CA  earthquake
# 2   NaN       NaN  0.60  ...      10 km ENE of Fox, Alaska  earthquake
# 3  62.0  0.013780  0.16  ...   15 km NE of Little Lake, CA  earthquake
# 4  99.0  0.002529  0.01  ...  10 km WNW of The Geysers, CA  earthquake
#
# ...

# %% [markdown]
# Key terms to mention
#
# time- Time when the event occurred.
# latitude - measures the distance north or south of the equator. measures y cords
# longitude - measures the distance east or west of the equator. measures x cords
# depth - the distance from the top or surface to the bottom of something.
# mag - the size of the earthquake, the great size or extent of something.

# %%
Earthquake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8886 entries, 0 to 8885
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time                 8886 non-null   object
#  1   latitude             8886 non-null   float64
#  2   longitude            8886 non-null   float64
#  3   depth                8886 non-null   float64
#  4   mag                  8886 non-null   float64
#  5   magType              8886 non-null   object
#  6   nst                  7092 non-null   float64
#  7   gap                  7092 non-null   float64
#  8   dmin                 5965 non-null   float64
#  9   rms                  8886 non-null   float64
#  10  net                  8886 non-null   object
#  11  id                   8886 non-null   object
#  12  updated              8886 non-null   object
#  13  place                8886 non-null   object
#  14  type                 8886 non-null   object
# ...

# %%
#checking for missing values

Earthquake.isnull().sum()
# Out:
# time                      0
# latitude                  0
# longitude                 0
# depth                     0
# mag                       0
# magType                   0
# nst                    1794
# gap                    1794
# dmin                   2921
# rms                       0
# net                       0
# id                        0
# updated                   0
# place                     0
# type                      0
# horizontalError        2537
# depthError                0
# magError               1810
# magNst                 1796
# status                    0
# locationSource            0
# magSource                 0
# numberofearthquakes       0
# dtype: int64

# %%
# Drop rows with missing values
#Earthquake_cleaned = Earthquake.dropna()

# Display the cleaned DataFrame
#print(Earthquake_cleaned)

#I was going to remove the entries with missing data, but then i decided that i will only be taking the data from the sets that is fully entered

# %%
Earthquake.tail()
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 8881  2023-12-19T02:43:10.876Z  -7.242500  119.138700  593.76  4.90      mb
# 8882  2023-12-19T02:42:29.472Z -22.785000  172.366200   10.00  5.30     mww
# 8883  2023-12-19T02:39:21.180Z  33.111333 -115.624833    9.51  1.34      ml
# 8884  2023-12-19T02:35:17.230Z  38.826332 -122.804833    3.06  0.64      md
# 8885  2023-12-19T02:34:46.768Z  57.893500 -153.765300   56.30  1.50      ml
#
#        nst    gap      dmin   rms  ...                             place  \
# 8881  95.0   26.0  2.074000  0.75  ...     142 km NNE of Bima, Indonesia
# 8882  64.0   74.0  4.546000  0.74  ...  southeast of the Loyalty Islands
# 8883  32.0   93.0  0.066410  0.19  ...         8 km N of Westmorland, CA
# 8884   8.0  147.0  0.005036  0.01  ...        7 km NW of The Geysers, CA
# 8885   NaN    NaN       NaN  0.32  ...   41 km NNE of Larsen Bay, Alaska
#
# ...

# %%
Earthquake.groupby(['place']).sum(numeric_only=True)
# Out:
#                                        latitude   longitude  depth    mag  \
# place
# 0 km E of Aguanga, CA                 33.443167 -116.862667  14.35   0.77
# 0 km E of Notiechtown, Oklahoma       35.576667  -95.085833   6.24   1.43
# 0 km E of Pacheco, CA                 37.984167 -122.069500  15.44   2.05
# 0 km ENE of Eatonville, Washington    46.869333 -122.254667  -0.29   1.43
# 0 km ENE of Incline Village, Nevada   39.252600 -119.967400   3.10   0.40
# ...                                         ...         ...    ...    ...
# southeast of the Loyalty Islands     -22.785000  172.366200  10.00   5.30
# southern East Pacific Rise          -234.216100 -588.433500  50.00  26.70
# southern Mid-Atlantic Ridge          -68.332000  -20.325100  20.00  10.00
# southwest of Africa                  -52.246400   13.489800  10.00   5.40
# western Indian-Antarctic Ridge       -49.838600  115.231900  10.00   5.20
#
# ...

# %%
top_5_earthquakes = Earthquake.nlargest(5, "mag")[['time','latitude', 'longitude', 'depth', 'mag', 'place']]
print(top_5_earthquakes)
# Out:
#                           time  latitude  longitude    depth  mag  \
# 4164  2024-01-01T07:10:09.692Z   37.4976   137.2416   10.000  7.5
# 2140  2024-01-08T20:48:42.916Z    4.8606   126.1861   68.017  6.7
# 5637  2023-12-28T09:15:15.393Z   44.5796   148.9903   23.844  6.5
# 1515  2024-01-11T09:20:26.809Z   36.5061    70.5994  206.561  6.4
# 4707  2023-12-30T17:16:24.043Z   -2.9536   139.3518   33.000  6.3
#
#                                       place
# 4164  2024 Noto Peninsula, Japan Earthquake
# 2140    100 km SE of Sarangani, Philippines
# 5637          113 km SE of Kuril’sk, Russia
# 1515         44 km SSW of Jurm, Afghanistan
# 4707       147 km WSW of Abepura, Indonesia

# %%
# Select the top 5 earthquakes based on the 'mag' column
top_5_earthquakes = Earthquake.nlargest(5, 'mag')

# Plot all earthquakes
plt.scatter(Earthquake['longitude'], Earthquake['latitude'], label='All Earthquakes', color= 'pink', alpha=0.5)

# Highlight the top 5 earthquakes with a different color or marker
plt.scatter(top_5_earthquakes['longitude'], top_5_earthquakes['latitude'], color='black', label='Top 5 Earthquakes(based on magnitude)', marker='x')

# Set labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Earthquakes - All and Top 5 Highlighted')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
Earthquake.hist(color="hotpink")
fig.tight_layout()

# %%
plt.hist(Earthquake['mag'], bins=20, color= 'pink', edgecolor='black', alpha=0.7)

# Set labels and title
plt.xlabel('Magnitude')
plt.ylabel('Number of Earthquakes')
plt.title('Distribution of Earthquake Magnitudes')

# Show the plot
plt.show()

# %%
top_20_earthquakes = Earthquake.nlargest(20, 'mag')

plt.figure(figsize=(12, 8))
sns.barplot(x='mag', y='place', data=top_20_earthquakes, palette='RdPu')
plt.title('Top 20 Earthquakes by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Place')
plt.show()

#decided not to use this in data presentation

# %%
# bar plot for places 
plt.figure(figsize=(12, 8))
sns.barplot(x='mag', y='place', data=top_5_earthquakes, palette='RdPu')
plt.title('Top 5 Earthquakes by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Place')
plt.show()
# Out:
# /var/folders/ql/6vx125nn1rq0s_rqskvt5bh40000gn/T/ipykernel_3964/2719466060.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='mag', y='place', data=top_5_earthquakes, palette='RdPu')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert 'time' to datetime format wtih to_datime function
Earthquake['time'] = pd.to_datetime(Earthquake['time'])

# Group by date and count the number of earthquakes
daily_counts = Earthquake.groupby(Earthquake['time'].dt.date).size().reset_index(name='total')

# Plotting the time series
plt.figure(figsize=(12, 8))
plt.plot(daily_counts['time'], daily_counts['total'], marker='o', linestyle='-', color='hotpink')
plt.title('Total Earthquakes Over Time')
plt.xlabel('Date')
plt.ylabel('Total Earthquakes')
plt.show()
