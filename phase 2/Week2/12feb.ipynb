# %% [markdown]
# 14th of feb notes too
# includes:
#
# 3 SVM AKA Support Vector Machines
#
# Decision tree:
#
#
# kNN model:
#
#  we use the encoder function to change the numbers into columns
#
# what does encode mean?
#
# means to convert and in Data Science/Machine Learning: Encoding often refers to the process of representing categorical variables as numerical values.

# %%
#import libaries

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
from math import sqrt

# %%
data = pd.read_csv('fruit_types.csv') #loading data

encoder = preprocessing.LabelEncoder() # creating a label Encoder

#converting strings to numbers
fruit_name_enocded=encoder.fit_transform(data.iloc[:,0])
fruit_subtype_encoded=encoder.fit_transform(data.iloc[:,1])
mass_encoded=encoder.fit_transform(data.iloc[:,2])
width_encoded=encoder.fit_transform(data.iloc[:,3])
height_encoded=encoder.fit_transform(data.iloc[:,4])

#combining encoded data

data=list(zip(fruit_name_enocded,fruit_subtype_encoded,mass_encoded,width_encoded,height_encoded))
data = pd.DataFrame(data, columns= ['fruit_name', 'fruit_subtype', 'mass', 'width', 'height'])

#define features/target 

data_to_use = data.iloc[:,1:5]
data_to_target = data.iloc[:,0]

X_train, X_test, y_train, y_test = train_test_split(data_to_use, data_to_target, test_size=0.2, random_state=123)
# 80% training and 20% test
#what does that mean

knn_model = KNeighborsClassifier(n_neighbors=3) #define kNN model with k=3 

knn_model.fit(X_train, y_train) #fit kNN model
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#making the prediction 
y_pred = knn_model.predict(X_test)

#accuracy 
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))

#mean r squared error 
print("RMSE:", sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Accuracy: 0.8333333333333334
# RMSE: 0.816496580927726

# %%
#read file
import pandas as pd
df = pd.read_excel('Practical.xlsx')
df
# Out:
#        food_name           date_added        date_modified  \
# 0      succotash  2019-07-17 00:00:00  2019-10-16 00:00:00
# 1         entree  2018-08-27 00:00:00  2019-12-24 00:00:00
# 2         lychee  2018-12-24 00:00:00  2019-11-04 00:00:00
# 3         cashew  2018-11-04 00:00:00  2019-01-23 00:00:00
# 4         millet  2019-05-09 00:00:00  2019-06-04 00:00:00
# ..           ...                  ...                  ...
# 399        honey  2019-01-23 00:00:00  2019-04-21 00:00:00
# 400        syrup                  NaN  2019-09-04 00:00:00
# 401    milkshake  2019-12-19 00:00:00  2019-12-30 00:00:00
# 402       celery  2019-08-25 00:00:00  2019-11-07 00:00:00
# 403  dragonfruit  2019-05-18 00:00:00  2019-08-28 00:00:00
#
#     total_sales & online_sales  approved
# 0                  2488 (1634)       1.0
# 1                   2801 (496)       1.0
# 2                   2706 (474)       1.0
# 3                   788 (2535)       1.0
# 4                  4931 (3637)       1.0
# ...

# %%
# DECISION TREE
# GINI
## MAX DEPTH
# ENTROPY


#import needed 
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import metrics

data = pd.read_csv('fruit_types.csv')

encoder = preprocessing.LabelEncoder()

#converting strings to numbers
fruit_name_enocded=encoder.fit_transform(data.iloc[:,0])
fruit_subtype_encoded=encoder.fit_transform(data.iloc[:,1])
mass_encoded=encoder.fit_transform(data.iloc[:,2])
width_encoded=encoder.fit_transform(data.iloc[:,3])
height_encoded=encoder.fit_transform(data.iloc[:,4])

#combining encoded data

data=list(zip(fruit_name_enocded,fruit_subtype_encoded,mass_encoded,width_encoded,height_encoded))
data = pd.DataFrame(data, columns= ['fruit_name', 'fruit_subtype', 'mass', 'width', 'height'])

## GINI
decision_gini = DecisionTreeClassifier()

## USE MAX DEPTH
decision_depth = DecisionTreeClassifier(max_depth=3)

#entropy 

decision_entropy = DecisionTreeClassifier(criterion='entropy')

# %%
## fit the tree

decision_gini.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
decision_depth.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
decision_entropy.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# now model training is done we can now do the preditions

# %%
## PREDICTION

y_pred_gini = decision_gini.predict(X_test)
y_pred_depth3 = decision_depth.predict(X_test)
y_pred_entropy = decision_entropy.predict(X_test)
#print
#accuracy 
print("Accuracy (G):", metrics.accuracy_score(y_test, y_pred_gini))

print("Accuracy (E):", (metrics.mean_squared_error(y_test, y_pred_entropy)))

print("Accuracy (D):", metrics.accuracy_score(y_test, y_pred_depth3))
# Out:
# Accuracy (G): 1.0
# Accuracy (E): 0.0
# Accuracy (D): 0.9166666666666666

# %% [markdown]
# why results keep chnagin

# %%
###3SVMs

#import needed 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics, svm

data = pd.read_csv('fruit_types.csv')

## prepare data

# %%
# create the SVM

clfLinear= svm.SVC(kernel='linear')
clfsigmoid= svm.SVC(kernel='sigmoid')
clfrbf= svm.SVC(kernel='rbf')

# %%
## train the model 

clfLinear.fit(X_train, y_train)
clfsigmoid.fit(X_train, y_train)
clfrbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
#PREDICTION
 
y_pred_linear = clfLinear.predict(X_test)
y_pred_sigmoid = clfsigmoid.predict(X_test)
y_pred_rbf = clfrbf.predict(X_test)

# %%
###calculate acuracy 


print("Accuracy (L):", (metrics.accuracy_score(y_test, y_pred_linear)))
print("Accuracy (S):", (metrics.accuracy_score(y_test, y_pred_sigmoid)))
print("Accuracy (R):", (metrics.accuracy_score(y_test, y_pred_rbf)))
# Out:
# Accuracy (L): 0.9166666666666666
# Accuracy (S): 0.5
# Accuracy (R): 0.9166666666666666
